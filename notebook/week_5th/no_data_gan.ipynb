# %%
from no_data_gan.train import main

model = main()
# Out:
# using cuda
# ...
# epoch:30 loss:1.0830516815185547: 100%|██████████| 1563/1563 [02:07<00:00, 12.22it/s]

# %%
from no_data_gan.test import main

main(model)
# Out:
# using cuda
# c:\Workspaces\study-club\dl-with-pytorch\.venv\Lib\site-packages\torchvision\datasets\cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# Accuracy: 0.6073
