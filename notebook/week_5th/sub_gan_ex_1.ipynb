# %%
from no_data_gan.train_sub import main as teacher

model = teacher()
# Out:
# using cuda
# epoch0 S_loss: 1.9583591222763062
# epoch0 S_loss: 1.284326195716858
# epoch0 S_loss: 1.7228039503097534
# epoch0 S_loss: 1.3639081716537476
# epoch0 S_loss: 1.5683540105819702
# epoch0 G_loss: -1.4595543146133423
# epoch1 S_loss: 1.5597814321517944
# epoch1 S_loss: 1.3991893529891968
# epoch1 S_loss: 1.4825423955917358
# epoch1 S_loss: 1.3259475231170654
# epoch1 S_loss: 1.3132795095443726
# epoch1 G_loss: -1.2366962432861328
# epoch2 S_loss: 1.2938361167907715
# epoch2 S_loss: 1.277375340461731
# epoch2 S_loss: 1.1964406967163086
# epoch2 S_loss: 1.2430568933486938
# epoch2 S_loss: 1.1787471771240234
# epoch2 G_loss: -1.1018975973129272
# epoch3 S_loss: 1.1517642736434937
# epoch3 S_loss: 1.1473056077957153
# epoch3 S_loss: 1.1197948455810547
# epoch3 S_loss: 1.0236479043960571
# epoch3 S_loss: 1.1678882837295532
# epoch3 G_loss: -0.9750643968582153
# epoch4 S_loss: 0.9839760661125183
# epoch4 S_loss: 1.1713587045669556
# epoch4 S_loss: 1.052133560180664
# ...

# %%
from no_data_gan.test_sub import main as student

student(model)
# Out:
# using cuda
# c:\Workspaces\study-club\dl-with-pytorch\.venv\Lib\site-packages\torchvision\datasets\cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# Accuracy:0.12112
# Accuracy:0.1211
